# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="278dfc0fb2cd4025adb5f11c0e54beca", client_secret="c10ddcf0a0014a42932045d83eae9618")

# %%
# Spotify Object
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
# Link to playlist ("Top 50 - Global") to extract data from
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF?si=3c950d065c274b3f"

# %%
# Extracts URI from link
playlist_uri = playlist_link.split("/")[-1].split("?")[0]

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-03-09T09:48:31Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_group': 'single',
#      'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
# ...

# %%
data['items'][0]['track']['name']
data['items'][0]['track']['album']['name']
data['items'][0]['track']['album']['album_group']
data['items'][0]['track']['album']['album_type']
# Out:
# 'Die For You - Remix'

# %%
track_artists = []
for idx,artist in enumerate(data['items'][0]['track']['artists']):
    track_artists.append(data['items'][0]['track']['artists'][idx]['name'])

track_artists
# Out:
# ['The Weeknd', 'Ariana Grande']

# %%
data['items'][0]['track']['id']
data['items'][0]['track']['duration_ms']
data['items'][0]['track']['explicit']
data['items'][0]['track']['popularity']
data['items'][0]['track']['album']['release_date']
data['items'][0]['track']['album']['external_urls']['spotify']
data['items'][0]['track']['album']['images'][1]['url']
# Out:
# 'https://i.scdn.co/image/ab67616d00001e028de12a274f6e1df6634f57ec'

# %%
# All Data extracted from Top 50 - Global Playlist
top_50_list =[]

for row in data['items']:
    track_name = row['track']['name']
    album_name = row['track']['album']['name']
    album_id = row['track']['album']['id']
    album_group = row['track']['album']['album_group']
    album_type = row['track']['album']['album_type']
    album_num_tracks = row['track']['album']['total_tracks']
    added_at = row['added_at']
    album_artists_list = []
    album_artists_id_list = []
    for idx,artist in enumerate(row['track']['album']['artists']):
        album_artists_list.append(row['track']['album']['artists'][idx]['name'])
        album_artists_id_list.append(row['track']['album']['artists'][idx]['id'])
    album_artists = ", ".join(album_artists_list)
    album_artists_ids = ", ".join(album_artists_id_list)

    track_artists_list = []
    track_artists_id_list = []
    for idx,artist in enumerate(row['track']['artists']):
        track_artists_list.append(row['track']['artists'][idx]['name'])
        track_artists_id_list.append(row['track']['artists'][idx]['id'])
    track_artists = ", ".join(track_artists_list)
    track_artists_ids = ", ".join(track_artists_id_list)
    
    track_number = row['track']['track_number']
    track_id = row['track']['id']
    track_duration = row['track']['duration_ms']
    is_explicit = row['track']['explicit']
    popularity = row['track']['popularity']
    release_date = row['track']['album']['release_date']
    album_image = row['track']['album']['images'][1]['url']

    top_50_data = {'track_id': track_id,
                  'track_name': track_name,
                  'track_number': track_number,
                  'album_name': album_name,
                  'album_id': album_id,
                  'album_artists': album_artists,
                  'album_artists_id': album_artists_ids,
                  'track_artists': track_artists,
                  'track_artists_id': track_artists_ids,
                  'album_group': album_group,
                  'album_type': album_type,
                  'total_tracks': album_num_tracks,
                  'track_duration': track_duration,
                  'release_date': release_date,
                  'added_at': added_at,
                  'is_explicit': is_explicit,
                  'popularity': popularity,
                  'album_image': album_image,
                }
    top_50_list.append(top_50_data)

# %%
top_50_list
# Out:
# [{'track_id': '7oDd86yk8itslrA9HRP2ki',
#   'track_name': 'Die For You - Remix',
#   'track_number': 1,
#   'album_name': 'Die For You (Remix)',
#   'album_id': '6Exo0MYoL3XammoTDeihFy',
#   'album_artists': 'The Weeknd, Ariana Grande',
#   'album_artists_id': '1Xyo4u8uXC1ZmMpatF05PJ, 66CXWjxzNUsdJxJ2JdwvnR',
#   'track_artists': 'The Weeknd, Ariana Grande',
#   'track_artists_id': '1Xyo4u8uXC1ZmMpatF05PJ, 66CXWjxzNUsdJxJ2JdwvnR',
#   'album_group': 'single',
#   'album_type': 'single',
#   'total_tracks': 1,
#   'track_duration': 232857,
#   'release_date': '2023-02-24',
#   'added_at': '2023-03-09T09:48:31Z',
#   'is_explicit': False,
#   'popularity': 92,
#   'album_image': 'https://i.scdn.co/image/ab67616d00001e028de12a274f6e1df6634f57ec'},
#  {'track_id': '0DWdj2oZMBFSzRsi2Cvfzf',
#   'track_name': 'TQG',
#   'track_number': 6,
#   'album_name': 'MAÑANA SERÁ BONITO',
#   'album_id': '4kS7bSuU0Jm9LYMosFU2x5',
#   'album_artists': 'KAROL G',
# ...

# %%
# Data Specific to Albums
album_list =[]

for row in data['items']:
    album_name = row['track']['album']['name']
    album_id = row['track']['album']['id']
    album_group = row['track']['album']['album_group']
    album_type = row['track']['album']['album_type']
    album_num_tracks = row['track']['album']['total_tracks']
    album_artists_list = []
    album_artists_id_list = []
    for idx,artist in enumerate(row['track']['album']['artists']):
        album_artists_list.append(row['track']['album']['artists'][idx]['name'])
        album_artists_id_list.append(row['track']['album']['artists'][idx]['id'])
    album_artists = ", ".join(album_artists_list)
    album_artists_ids = ", ".join(album_artists_id_list)

    release_date = row['track']['album']['release_date']
    album_image = row['track']['album']['images'][1]['url']

    album_data = {'album_id': album_id,
                  'album_name': album_name,
                  'album_artists': album_artists,
                  'album_artists_id': album_artists_ids,
                  'album_group': album_group,
                  'album_type': album_type,
                  'total_tracks': album_num_tracks,
                  'release_date': release_date,
                  'album_image': album_image
                }
    album_list.append(album_data)

# %%
album_list
# Out:
# [{'album_name': 'Die For You (Remix)',
#   'album_id': '6Exo0MYoL3XammoTDeihFy',
#   'album_artists': 'The Weeknd, Ariana Grande',
#   'album_artists_id': '1Xyo4u8uXC1ZmMpatF05PJ, 66CXWjxzNUsdJxJ2JdwvnR',
#   'album_group': 'single',
#   'album_type': 'single',
#   'total_tracks': 1,
#   'release_date': '2023-02-24',
#   'album_image': 'https://i.scdn.co/image/ab67616d00001e028de12a274f6e1df6634f57ec'},
#  {'album_name': 'MAÑANA SERÁ BONITO',
#   'album_id': '4kS7bSuU0Jm9LYMosFU2x5',
#   'album_artists': 'KAROL G',
#   'album_artists_id': '790FomKkXshlbRYZFtlgla',
#   'album_group': 'album',
#   'album_type': 'album',
#   'total_tracks': 17,
#   'release_date': '2023-02-24',
#   'album_image': 'https://i.scdn.co/image/ab67616d00001e0282de1ca074ae63cb18fce335'},
#  {'album_name': 'Flowers',
#   'album_id': '7I0tjwFtxUwBC1vgyeMAax',
#   'album_artists': 'Miley Cyrus',
#   'album_artists_id': '5YGY8feqx7naU7z4HrwZM6',
#   'album_group': 'single',
#   'album_type': 'single',
# ...

# %%
artist_list =[]

for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id': artist['id'],
                               'artist_name': artist['name']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ', 'artist_name': 'The Weeknd'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR', 'artist_name': 'Ariana Grande'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla', 'artist_name': 'KAROL G'},
#  {'artist_id': '0EmeFodog0BfCgMzAIvKQp', 'artist_name': 'Shakira'},
#  {'artist_id': '5YGY8feqx7naU7z4HrwZM6', 'artist_name': 'Miley Cyrus'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP', 'artist_name': 'SZA'},
#  {'artist_id': '78rUTD7y6Cy67W1RVzYs7t', 'artist_name': 'PinkPantheress'},
#  {'artist_id': '3LZZPxNDGDFVSIPqf4JuEf', 'artist_name': 'Ice Spice'},
#  {'artist_id': '6KImCVD70vtIoJWnq6nGn3', 'artist_name': 'Harry Styles'},
#  {'artist_id': '716NhGYqD1jl2wI1Qkgq36', 'artist_name': 'Bizarrap'},
#  {'artist_id': '0EmeFodog0BfCgMzAIvKQp', 'artist_name': 'Shakira'},
#  {'artist_id': '0iEtIxbK0KxaSlF7G42ZOp', 'artist_name': 'Metro Boomin'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ', 'artist_name': 'The Weeknd'},
# ...

# %%
song_list =[]

for row in data['items']:
    track_id = row['track']['id']
    track_name = row['track']['name']
    album_id = row['track']['album']['id']
    added_at = row['added_at']

    track_artists_id_list = []
    for idx,artist in enumerate(row['track']['artists']):
        track_artists_id_list.append(row['track']['artists'][idx]['id'])
    track_artists_ids = ", ".join(track_artists_id_list)
    
    track_number = row['track']['track_number']
    track_duration = row['track']['duration_ms']
    is_explicit = row['track']['explicit']
    popularity = row['track']['popularity']

    song_data = {'track_id': track_id,
                  'track_name': track_name,
                  'track_number': track_number,
                  'album_id': album_id,
                  'track_artists_id': track_artists_ids,
                  'track_duration': track_duration,
                  'added_at': added_at,
                  'is_explicit': is_explicit,
                  'popularity': popularity,
                }
    song_list.append(song_data)

# %%
song_list
# Out:
# [{'track_id': '7oDd86yk8itslrA9HRP2ki',
#   'track_name': 'Die For You - Remix',
#   'track_number': 1,
#   'album_id': '6Exo0MYoL3XammoTDeihFy',
#   'track_artists_id': '1Xyo4u8uXC1ZmMpatF05PJ, 66CXWjxzNUsdJxJ2JdwvnR',
#   'track_duration': 232857,
#   'added_at': '2023-03-09T09:48:31Z',
#   'is_explicit': False,
#   'popularity': 92},
#  {'track_id': '0DWdj2oZMBFSzRsi2Cvfzf',
#   'track_name': 'TQG',
#   'track_number': 6,
#   'album_id': '4kS7bSuU0Jm9LYMosFU2x5',
#   'track_artists_id': '790FomKkXshlbRYZFtlgla, 0EmeFodog0BfCgMzAIvKQp',
#   'track_duration': 197933,
#   'added_at': '2023-03-09T09:48:31Z',
#   'is_explicit': True,
#   'popularity': 92},
#  {'track_id': '0yLdNVWF3Srea0uzk55zFn',
#   'track_name': 'Flowers',
#   'track_number': 1,
#   'album_id': '7I0tjwFtxUwBC1vgyeMAax',
#   'track_artists_id': '5YGY8feqx7naU7z4HrwZM6',
#   'track_duration': 200454,
#   'added_at': '2023-03-09T09:48:31Z',
#   'is_explicit': False,
#   'popularity': 100},
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df
# Out:
#                   album_id                                      album_name  \
# 0   6Exo0MYoL3XammoTDeihFy                             Die For You (Remix)
# 1   4kS7bSuU0Jm9LYMosFU2x5                              MAÑANA SERÁ BONITO
# 2   7I0tjwFtxUwBC1vgyeMAax                                         Flowers
# 3   1nrVofqDRs7cpWXJ49qTnP                                             SOS
# 4   6cVfHBcp3AdpYY0bBglkLN                              Boy's a liar Pt. 2
# 5   5r36AJ6VOJtp00oxSkBZ5h                                   Harry's House
# 6   1gi2iwr1l8IUyHYHxi01pg           Shakira: Bzrp Music Sessions, Vol. 53
# 7   7txGsnDSqVMoRl6RQ9XyZP                               HEROES & VILLAINS
# 8   5xefnzEqKIWnmTWYFzekGZ                                     Resistencia
# 9   2b2GHWESCWEuHiCZ2Skedp                   Calm Down (with Selena Gomez)
# 10  3Uq1jNGnD412ZvCb6j2DKV                                          Gloria
# ...

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                  artist_id        artist_name
# 0   1Xyo4u8uXC1ZmMpatF05PJ         The Weeknd
# 1   66CXWjxzNUsdJxJ2JdwvnR      Ariana Grande
# 2   790FomKkXshlbRYZFtlgla            KAROL G
# 3   0EmeFodog0BfCgMzAIvKQp            Shakira
# 4   5YGY8feqx7naU7z4HrwZM6        Miley Cyrus
# ..                     ...                ...
# 75  3TVXtAsR1Inumwj472S9r4              Drake
# 76  1URnnhqYAYcrqrcwql10ft          21 Savage
# 77  4O15NlyKLIASxsJ0PrXPfz       Lil Uzi Vert
# 78  0M2CO5ijP35MDhNwvpgxTV  sped up nightcore
# 79  2xzyIzdjfeXX6FIQtlAAyw       ARIZONATEARS
#
# [80 rows x 2 columns]

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df
# Out:
#                  artist_id        artist_name
# 0   1Xyo4u8uXC1ZmMpatF05PJ         The Weeknd
# 1   66CXWjxzNUsdJxJ2JdwvnR      Ariana Grande
# 2   790FomKkXshlbRYZFtlgla            KAROL G
# 3   0EmeFodog0BfCgMzAIvKQp            Shakira
# 4   5YGY8feqx7naU7z4HrwZM6        Miley Cyrus
# ..                     ...                ...
# 72  0ys2OFYzWYB5hRDLCsBqxt      Fuerza Regida
# 73  6XkjpgcEsYab502Vr1bBeW     Grupo Frontera
# 75  3TVXtAsR1Inumwj472S9r4              Drake
# 78  0M2CO5ijP35MDhNwvpgxTV  sped up nightcore
# 79  2xzyIzdjfeXX6FIQtlAAyw       ARIZONATEARS
#
# [61 rows x 2 columns]

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                   track_id                                         track_name  \
# 0   7oDd86yk8itslrA9HRP2ki                                Die For You - Remix
# 1   0DWdj2oZMBFSzRsi2Cvfzf                                                TQG
# 2   0yLdNVWF3Srea0uzk55zFn                                            Flowers
# 3   1Qrg8KqiBpW07V7PNxwwwL                                          Kill Bill
# 4   6AQbmUe0Qwf5PZnt4HmTXv                                 Boy's a liar Pt. 2
# 5   4Dvkj6JhhA12EX05fT7y2e                                          As It Was
# 6   4nrPB8O7Y7wsOCJdgXkthe              Shakira: Bzrp Music Sessions, Vol. 53
# 7   2dHHgzDwk4BJdRwy9uXhTO             Creepin' (with The Weeknd & 21 Savage)
# 8   4FAKtPVycI4DxoOHC01YqD                                         Yandel 150
# 9   0WtM2NBVQNNJLh6scP13H8                      Calm Down (with Selena Gomez)
# 10  0NZPBYD5qbEWRs3PrGiRkT                          Unholy (feat. Kim Petras)
# ...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
# Out:
# C:\Users\Jesus Marron\AppData\Local\Temp\ipykernel_24108\3126744046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   album_id          48 non-null     object
#  1   album_name        48 non-null     object
#  2   album_artists     48 non-null     object
#  3   album_artists_id  48 non-null     object
#  4   album_group       48 non-null     object
#  5   album_type        48 non-null     object
#  6   total_tracks      48 non-null     int64
#  7   release_date      48 non-null     datetime64[ns]
#  8   album_image       48 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 3.8+ KB

# %%
album_df.head()
# Out:
#                  album_id           album_name              album_artists  \
# 0  6Exo0MYoL3XammoTDeihFy  Die For You (Remix)  The Weeknd, Ariana Grande
# 1  4kS7bSuU0Jm9LYMosFU2x5   MAÑANA SERÁ BONITO                    KAROL G
# 2  7I0tjwFtxUwBC1vgyeMAax              Flowers                Miley Cyrus
# 3  1nrVofqDRs7cpWXJ49qTnP                  SOS                        SZA
# 4  6cVfHBcp3AdpYY0bBglkLN   Boy's a liar Pt. 2  PinkPantheress, Ice Spice
#
#                                  album_artists_id album_group album_type  \
# 0  1Xyo4u8uXC1ZmMpatF05PJ, 66CXWjxzNUsdJxJ2JdwvnR      single     single
# 1                          790FomKkXshlbRYZFtlgla       album      album
# 2                          5YGY8feqx7naU7z4HrwZM6      single     single
# 3                          7tYKF4w9nC0nq9CsPZTHyP       album      album
# 4  78rUTD7y6Cy67W1RVzYs7t, 3LZZPxNDGDFVSIPqf4JuEf      single     single
#
#    total_tracks release_date  \
# 0             1   2023-02-24
# ...

# %%
song_df['added_at'] = pd.to_datetime(song_df['added_at'], format='%Y%m%d')

# %%
song_df.head()
# Out:
#                  track_id           track_name  track_number  \
# 0  7oDd86yk8itslrA9HRP2ki  Die For You - Remix             1
# 1  0DWdj2oZMBFSzRsi2Cvfzf                  TQG             6
# 2  0yLdNVWF3Srea0uzk55zFn              Flowers             1
# 3  1Qrg8KqiBpW07V7PNxwwwL            Kill Bill             2
# 4  6AQbmUe0Qwf5PZnt4HmTXv   Boy's a liar Pt. 2             1
#
#                  album_id                                track_artists_id  \
# 0  6Exo0MYoL3XammoTDeihFy  1Xyo4u8uXC1ZmMpatF05PJ, 66CXWjxzNUsdJxJ2JdwvnR
# 1  4kS7bSuU0Jm9LYMosFU2x5  790FomKkXshlbRYZFtlgla, 0EmeFodog0BfCgMzAIvKQp
# 2  7I0tjwFtxUwBC1vgyeMAax                          5YGY8feqx7naU7z4HrwZM6
# 3  1nrVofqDRs7cpWXJ49qTnP                          7tYKF4w9nC0nq9CsPZTHyP
# 4  6cVfHBcp3AdpYY0bBglkLN  78rUTD7y6Cy67W1RVzYs7t, 3LZZPxNDGDFVSIPqf4JuEf
#
#    track_duration                  added_at  is_explicit  popularity
# 0          232857 2023-03-09 09:48:31+00:00        False          92
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          50 non-null     object
#  1   track_name        50 non-null     object
#  2   track_number      50 non-null     int64
#  3   album_id          50 non-null     object
#  4   track_artists_id  50 non-null     object
#  5   track_duration    50 non-null     int64
#  6   added_at          50 non-null     datetime64[ns, UTC]
#  7   is_explicit       50 non-null     bool
#  8   popularity        50 non-null     int64
# dtypes: bool(1), datetime64[ns, UTC](1), int64(3), object(4)
# memory usage: 3.3+ KB
